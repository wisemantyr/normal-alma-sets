# %%
import pandas as pd
import os
import re

# %%
lost_path = "lost_results.csv" 
lost_df = pd.read_csv(lost_path)
lost_df
# Out:
#                               Type / Creator / Imprint  \
# 0          Book By Lawrence, Mark (Ace Books 20170404)
# 1            Book By Livesey, Margot (Harper 20160927)
# 2    Book By Smith, Pamela H., (Ann Arbor : Univers...
# 3    Book By Csikszentmihalyi, Mihaly. (Oxford ; Ne...
# 4    Book By Ong, Anthony D. (Oxford ; New York : O...
# ..                                                 ...
# 337       Book By Weldon, Fay. (Head of Zeus 20180401)
# 338  Book By Sharp, Zoë, (Houston : Busted Flush P...
# 339  Book By Paul, Pamela. (Henry Holt & Company 20...
# 340  Music By Smith, Jean Edward. (Santa Ana, CA : ...
# 341  Book By Obama, Michelle, (Crown Publishing Gro...
#
#                                                  title         Barcode  \
# 0                                           Red Sister  33082012289335
# 1                                              Mercury  33082012283122
# 2    Ways of making and knowing : the material cult...  33082011802245
# 3    A life worth living : contributions to positiv...  33082009480889
# 4    Oxford handbook of methods in positive psychol...  33082009900084
# ..                                                 ...             ...
# 337                               Death of a She Devil  33082012492483
# 338                      Killer instinct / Zoë Sharp.  33082010926482
# 339  By the Book: Writers on Literature and the Lit...  33082011885943
# 340      FDR [sound recording] / by Jean Edward Smith.  33082010194065
# 341                                           Becoming  33082012290283
#
#      Inventory Number  Receiving Number                      Library  \
# 0                 NaN               NaN  Boatwright Memorial Library
# 1                 NaN               NaN  Boatwright Memorial Library
# 2                 NaN               NaN  Boatwright Memorial Library
# 3                 NaN               NaN  Boatwright Memorial Library
# 4                 NaN               NaN  Boatwright Memorial Library
# ..                ...               ...                          ...
# 337               NaN               NaN  Boatwright Memorial Library
# 338               NaN               NaN  Boatwright Memorial Library
# 339               NaN               NaN  Boatwright Memorial Library
# 340               NaN               NaN  Boatwright Memorial Library
# 341               NaN               NaN  Boatwright Memorial Library
#
#      Library Unit  Temporary Library         Creation Date  \
# 0             NaN                NaN   9/19/2017 20:00:00
# 1             NaN                NaN   9/17/2017 20:00:00
# 2             NaN                NaN   5/12/2015 20:00:00
# 3             NaN                NaN    7/5/2006 20:00:00
# 4             NaN                NaN    1/7/2007 19:00:00
# ..            ...                ...                   ...
# 337           NaN                NaN    5/5/2019 20:00:00
# 338           NaN                NaN  10/25/2010 20:00:00
# 339           NaN                NaN    1/7/2016 19:00:00
# 340           NaN                NaN   4/21/2008 20:00:00
# 341           NaN                NaN   4/30/2019 20:00:00
#
#         Modification Date  ...    Material Type  Copy ID  Description  \
# 0     11/8/2020 19:05:43   ...             Book      0.0          NaN
# 1     11/8/2020 19:04:04   ...             Book      0.0          NaN
# 2     11/8/2020 19:01:33   ...             Book      0.0          NaN
# 3     11/8/2020 19:01:30   ...             Book      0.0          NaN
# 4     11/8/2020 19:01:23   ...             Book      0.0          NaN
# ..                    ...  ...              ...      ...          ...
# 337   11/7/2020 19:02:04   ...             Book      0.0          NaN
# 338   10/5/2020 14:54:24   ...             Book      0.0          NaN
# 339   6/23/2020 02:03:26   ...             Book      0.0          NaN
# 340   6/23/2020 02:01:49   ...  Sound Recording      0.0          NaN
# 341  10/14/2020 10:44:10   ...             Book      0.0          NaN
#
#      Unnamed: 36  Orders  Requests Peer Reviewed            Item ID  \
# 0            NaN       0         0           NaN   2389850570006241
# 1            NaN       0         0           NaN  23109310650006241
# 2            NaN       0         0           NaN  23113347350006241
# 3            NaN       0         0           NaN  23112280520006241
# 4            NaN       0         0           NaN  23106540950006241
# ..           ...     ...       ...           ...                ...
# 337          NaN       0         0           NaN  23127721560006241
# 338          NaN       0         0           NaN  23122350410006241
# 339          NaN       0         0           NaN  23101964170006241
# 340          NaN       0         0           NaN  23107874420006241
# 341          NaN       0         0           NaN  23127768500006241
#
#            Holdings ID            MMS ID
# 0     2289850580006241  9922033313606241
# 1    22109310660006241  9922023283606241
# 2    22113347360006241  9917370583606241
# 3    22112280530006241   998483803606241
# 4    22106540960006241   998635113606241
# ..                 ...               ...
# 337  22127721570006241  9924929003606241
# 338  22122350420006241  9911598563606241
# 339  22101964180006241  9918118073606241
# 340  22107874430006241   999363343606241
# 341  22127768510006241  9924928363606241
#
# [342 rows x 43 columns]

# %%
lost_df.columns
# Out:
# Index(['Type / Creator / Imprint', 'title', 'Barcode', 'Inventory Number',
#        'Receiving Number', 'Library', 'Library Unit', 'Temporary Library',
#        'Creation Date', 'Modification Date', 'Process type', 'To Library',
#        'Expected Arrival Time', 'At Library', 'At', 'On Hold Expiration Date',
#        'Due Date', 'Needed By', 'Until', 'Permanent Location',
#        'Temporary Location', 'Call Number', 'Call Number Type',
#        'Accession Number', 'Temporary Call Number',
#        'Temporary Call Number Type', 'Item call number',
#        'Item call number type', 'Status', 'RFID Security Status', 'Due back',
#        'Item Policy', 'Temporary Item Policy', 'Material Type', 'Copy ID',
#        'Description', 'Unnamed: 36', 'Orders', 'Requests', 'Peer Reviewed',
#        'Item ID', 'Holdings ID', 'MMS ID'],
#       dtype='object')

# %%
all_null_cols = lost_df.columns[lost_df.isna().all()].tolist()
all_null_cols
# Out:
# ['Inventory Number',
#  'Receiving Number',
#  'Library Unit',
#  'Temporary Library',
#  'To Library',
#  'Expected Arrival Time',
#  'At Library',
#  'At',
#  'On Hold Expiration Date',
#  'Needed By',
#  'Until',
#  'Temporary Location',
#  'Accession Number',
#  'Temporary Call Number',
#  'Temporary Call Number Type',
#  'Item call number',
#  'Item call number type',
#  'RFID Security Status',
#  'Due back',
#  'Temporary Item Policy',
#  'Unnamed: 36',
#  'Peer Reviewed']

# %%
lost_df = lost_df.drop(columns=all_null_cols)
lost_df.columns
# Out:
# Index(['Type / Creator / Imprint', 'title', 'Barcode', 'Library',
#        'Creation Date', 'Modification Date', 'Process type', 'Due Date',
#        'Permanent Location', 'Call Number', 'Call Number Type', 'Status',
#        'Item Policy', 'Material Type', 'Copy ID', 'Description', 'Orders',
#        'Requests', 'Item ID', 'Holdings ID', 'MMS ID'],
#       dtype='object')

# %%
lost_df=lost_df.drop(columns=["Library", "Call Number Type", "Item ID", "Holdings ID", "Process type", "Item Policy", "Creation Date"])
lost_df.columns
# Out:
# Index(['Type / Creator / Imprint', 'title', 'Barcode', 'Modification Date',
#        'Due Date', 'Permanent Location', 'Call Number', 'Status',
#        'Material Type', 'Copy ID', 'Description', 'Orders', 'Requests',
#        'MMS ID'],
#       dtype='object')

# %%
lost_df.dtypes
# Out:
# Type / Creator / Imprint     object
# title                        object
# Barcode                       int64
# Modification Date            object
# Due Date                     object
# Permanent Location           object
# Call Number                  object
# Status                       object
# Material Type                object
# Copy ID                     float64
# Description                  object
# Orders                        int64
# Requests                      int64
# MMS ID                        int64
# dtype: object

# %%
any_null_cols = lost_df.columns[lost_df.isna().any()].tolist()
any_null_cols
# Out:
# ['Copy ID', 'Description']

# %%
mode = lost_df['Copy ID'].mode().values[0]
lost_df['Copy ID'].fillna(value=mode, inplace=True)
lost_df.dtypes
# Out:
# Type / Creator / Imprint     object
# title                        object
# Barcode                       int64
# Modification Date            object
# Due Date                     object
# Permanent Location           object
# Call Number                  object
# Status                       object
# Material Type                object
# Copy ID                     float64
# Description                  object
# Orders                        int64
# Requests                      int64
# MMS ID                        int64
# dtype: object

# %%
any_null_cols = lost_df.columns[lost_df.isna().any()].tolist()
any_null_cols
# Out:
# ['Description']

# %%
lost_df["Copy ID"] = lost_df["Copy ID"].astype(int)
lost_df.dtypes
# Out:
# Type / Creator / Imprint    object
# title                       object
# Barcode                      int64
# Modification Date           object
# Due Date                    object
# Permanent Location          object
# Call Number                 object
# Status                      object
# Material Type               object
# Copy ID                      int32
# Description                 object
# Orders                       int64
# Requests                     int64
# MMS ID                       int64
# dtype: object

# %%
lost_df["Copy ID"].unique()
# Out:
# array([0, 2, 3, 1])

# %%
lost_df["Modification Date"] = pd.to_datetime(lost_df["Modification Date"])
lost_df["Due Date"] = pd.to_datetime(lost_df["Due Date"])
lost_df.dtypes
# Out:
# Type / Creator / Imprint            object
# title                               object
# Barcode                              int64
# Modification Date           datetime64[ns]
# Due Date                    datetime64[ns]
# Permanent Location                  object
# Call Number                         object
# Status                              object
# Material Type                       object
# Copy ID                              int32
# Description                         object
# Orders                               int64
# Requests                             int64
# MMS ID                               int64
# dtype: object

# %%
lost_df
# Out:
#                               Type / Creator / Imprint  \
# 0          Book By Lawrence, Mark (Ace Books 20170404)
# 1            Book By Livesey, Margot (Harper 20160927)
# 2    Book By Smith, Pamela H., (Ann Arbor : Univers...
# 3    Book By Csikszentmihalyi, Mihaly. (Oxford ; Ne...
# 4    Book By Ong, Anthony D. (Oxford ; New York : O...
# ..                                                 ...
# 337       Book By Weldon, Fay. (Head of Zeus 20180401)
# 338  Book By Sharp, Zoë, (Houston : Busted Flush P...
# 339  Book By Paul, Pamela. (Henry Holt & Company 20...
# 340  Music By Smith, Jean Edward. (Santa Ana, CA : ...
# 341  Book By Obama, Michelle, (Crown Publishing Gro...
#
#                                                  title         Barcode  \
# 0                                           Red Sister  33082012289335
# 1                                              Mercury  33082012283122
# 2    Ways of making and knowing : the material cult...  33082011802245
# 3    A life worth living : contributions to positiv...  33082009480889
# 4    Oxford handbook of methods in positive psychol...  33082009900084
# ..                                                 ...             ...
# 337                               Death of a She Devil  33082012492483
# 338                      Killer instinct / Zoë Sharp.  33082010926482
# 339  By the Book: Writers on Literature and the Lit...  33082011885943
# 340      FDR [sound recording] / by Jean Edward Smith.  33082010194065
# 341                                           Becoming  33082012290283
#
#       Modification Date            Due Date    Permanent Location  \
# 0   2020-11-08 19:05:43 2020-09-16 22:00:00  Recreational Reading
# 1   2020-11-08 19:04:04 2020-09-16 22:00:00  Recreational Reading
# 2   2020-11-08 19:01:33 2020-09-16 22:00:00                 Books
# 3   2020-11-08 19:01:30 2020-09-16 22:00:00                 Books
# 4   2020-11-08 19:01:23 2020-09-16 22:00:00                 Books
# ..                  ...                 ...                   ...
# 337 2020-11-07 19:02:04 2020-09-16 22:00:00  Recreational Reading
# 338 2020-10-05 14:54:24 2011-01-04 01:00:00  Recreational Reading
# 339 2020-06-23 02:03:26 2020-02-04 22:00:00  Recreational Reading
# 340 2020-06-23 02:01:49 2020-02-03 22:00:00  Recreational Reading
# 341 2020-10-14 10:44:10 2020-01-02 05:00:00  Recreational Reading
#
#            Call Number             Status    Material Type  Copy ID  \
# 0                    F  Item not in place             Book        0
# 1                    F  Item not in place             Book        0
# 2      AZ101 .W39 2014  Item not in place             Book        0
# 3    BF204.6 .L54 2006  Item not in place             Book        0
# 4    BF204.6 .O94 2007  Item not in place             Book        0
# ..                 ...                ...              ...      ...
# 337                  F  Item not in place             Book        0
# 338                  M  Item not in place             Book        0
# 339                  N  Item not in place             Book        0
# 340                  N  Item not in place  Sound Recording        0
# 341                  N  Item not in place             Book        0
#
#     Description  Orders  Requests            MMS ID
# 0           NaN       0         0  9922033313606241
# 1           NaN       0         0  9922023283606241
# 2           NaN       0         0  9917370583606241
# 3           NaN       0         0   998483803606241
# 4           NaN       0         0   998635113606241
# ..          ...     ...       ...               ...
# 337         NaN       0         0  9924929003606241
# 338         NaN       0         0  9911598563606241
# 339         NaN       0         0  9918118073606241
# 340         NaN       0         0   999363343606241
# 341         NaN       0         0  9924928363606241
#
# [342 rows x 14 columns]

# %%
nov_lost_df= lost_df.loc[lost_df["Modification Date"].dt.month >= 11]
nov_lost_df
# Out:
#                               Type / Creator / Imprint  \
# 0          Book By Lawrence, Mark (Ace Books 20170404)
# 1            Book By Livesey, Margot (Harper 20160927)
# 2    Book By Smith, Pamela H., (Ann Arbor : Univers...
# 3    Book By Csikszentmihalyi, Mihaly. (Oxford ; Ne...
# 4    Book By Ong, Anthony D. (Oxford ; New York : O...
# ..                                                 ...
# 331  Book By Smith, Desire. (Atglen, PA : Schiffer ...
# 333  Book By Borsuk, Amaranth, (Cambridge, MA : The...
# 334  Book By Dorsheimer, Wesley. (New York : Hippoc...
# 336  Book By Walsh, Brighton (Berkley Publishing Gr...
# 337       Book By Weldon, Fay. (Head of Zeus 20180401)
#
#                                                  title         Barcode  \
# 0                                           Red Sister  33082012289335
# 1                                              Mercury  33082012283122
# 2    Ways of making and knowing : the material cult...  33082011802245
# 3    A life worth living : contributions to positiv...  33082009480889
# 4    Oxford handbook of methods in positive psychol...  33082009900084
# ..                                                 ...             ...
# 331  Fashionable clothing from the Sears catalogs :...  33082010381969
# 333                        The book / Amaranth Borsuk.  33082012427471
# 334  The newsletter handbook : how to write and pub...  33082005551501
# 336                                    Caged in Winter  33082012284047
# 337                               Death of a She Devil  33082012492483
#
#       Modification Date            Due Date    Permanent Location  \
# 0   2020-11-08 19:05:43 2020-09-16 22:00:00  Recreational Reading
# 1   2020-11-08 19:04:04 2020-09-16 22:00:00  Recreational Reading
# 2   2020-11-08 19:01:33 2020-09-16 22:00:00                 Books
# 3   2020-11-08 19:01:30 2020-09-16 22:00:00                 Books
# 4   2020-11-08 19:01:23 2020-09-16 22:00:00                 Books
# ..                  ...                 ...                   ...
# 331 2020-11-08 19:05:11 2020-09-16 22:00:00                 Books
# 333 2020-11-14 19:01:03 2020-09-24 17:00:00                 Books
# 334 2020-11-08 19:05:24 2020-09-16 22:00:00                 Books
# 336 2020-11-07 19:01:50 2020-09-16 22:00:00  Recreational Reading
# 337 2020-11-07 19:02:04 2020-09-16 22:00:00  Recreational Reading
#
#            Call Number             Status Material Type  Copy ID Description  \
# 0                    F  Item not in place          Book        0         NaN
# 1                    F  Item not in place          Book        0         NaN
# 2      AZ101 .W39 2014  Item not in place          Book        0         NaN
# 3    BF204.6 .L54 2006  Item not in place          Book        0         NaN
# 4    BF204.6 .O94 2007  Item not in place          Book        0         NaN
# ..                 ...                ...           ...      ...         ...
# 331    TT555 .S62 1998  Item not in place          Book        0         NaN
# 333       Z4 .B74 2018  Item not in place          Book        0         NaN
# 334  Z286.N46 D67 1993  Item not in place          Book        0         NaN
# 336                  F  Item not in place          Book        0         NaN
# 337                  F  Item not in place          Book        0         NaN
#
#      Orders  Requests            MMS ID
# 0         0         0  9922033313606241
# 1         0         0  9922023283606241
# 2         0         0  9917370583606241
# 3         0         0   998483803606241
# 4         0         0   998635113606241
# ..      ...       ...               ...
# 331       0         0  9910328073606241
# 333       0         0  9923787673606241
# 334       0         0   994906973606241
# 336       0         0  9919460473606241
# 337       0         0  9924929003606241
#
# [244 rows x 14 columns]

# %%
nov_lost_df["Modification Date"] = nov_lost_df["Modification Date"].dt.strftime('%d-%b')
nov_lost_df["Due Date"] = nov_lost_df["Due Date"].dt.strftime('%d-%b')
nov_lost_df
# Out:
# <ipython-input-16-2df7f2c95876>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nov_lost_df["Modification Date"] = nov_lost_df["Modification Date"].dt.strftime('%d-%b')
# <ipython-input-16-2df7f2c95876>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nov_lost_df["Due Date"] = nov_lost_df["Due Date"].dt.strftime('%d-%b')
#                               Type / Creator / Imprint  \
# 0          Book By Lawrence, Mark (Ace Books 20170404)
# 1            Book By Livesey, Margot (Harper 20160927)
# 2    Book By Smith, Pamela H., (Ann Arbor : Univers...
# 3    Book By Csikszentmihalyi, Mihaly. (Oxford ; Ne...
# 4    Book By Ong, Anthony D. (Oxford ; New York : O...
# ..                                                 ...
# 331  Book By Smith, Desire. (Atglen, PA : Schiffer ...
# 333  Book By Borsuk, Amaranth, (Cambridge, MA : The...
# 334  Book By Dorsheimer, Wesley. (New York : Hippoc...
# 336  Book By Walsh, Brighton (Berkley Publishing Gr...
# 337       Book By Weldon, Fay. (Head of Zeus 20180401)
#
#                                                  title         Barcode  \
# 0                                           Red Sister  33082012289335
# 1                                              Mercury  33082012283122
# 2    Ways of making and knowing : the material cult...  33082011802245
# 3    A life worth living : contributions to positiv...  33082009480889
# 4    Oxford handbook of methods in positive psychol...  33082009900084
# ..                                                 ...             ...
# 331  Fashionable clothing from the Sears catalogs :...  33082010381969
# 333                        The book / Amaranth Borsuk.  33082012427471
# 334  The newsletter handbook : how to write and pub...  33082005551501
# 336                                    Caged in Winter  33082012284047
# 337                               Death of a She Devil  33082012492483
#
#     Modification Date Due Date    Permanent Location        Call Number  \
# 0              08-Nov   16-Sep  Recreational Reading                  F
# 1              08-Nov   16-Sep  Recreational Reading                  F
# 2              08-Nov   16-Sep                 Books    AZ101 .W39 2014
# 3              08-Nov   16-Sep                 Books  BF204.6 .L54 2006
# 4              08-Nov   16-Sep                 Books  BF204.6 .O94 2007
# ..                ...      ...                   ...                ...
# 331            08-Nov   16-Sep                 Books    TT555 .S62 1998
# 333            14-Nov   24-Sep                 Books       Z4 .B74 2018
# 334            08-Nov   16-Sep                 Books  Z286.N46 D67 1993
# 336            07-Nov   16-Sep  Recreational Reading                  F
# 337            07-Nov   16-Sep  Recreational Reading                  F
#
#                 Status Material Type  Copy ID Description  Orders  Requests  \
# 0    Item not in place          Book        0         NaN       0         0
# 1    Item not in place          Book        0         NaN       0         0
# 2    Item not in place          Book        0         NaN       0         0
# 3    Item not in place          Book        0         NaN       0         0
# 4    Item not in place          Book        0         NaN       0         0
# ..                 ...           ...      ...         ...     ...       ...
# 331  Item not in place          Book        0         NaN       0         0
# 333  Item not in place          Book        0         NaN       0         0
# 334  Item not in place          Book        0         NaN       0         0
# 336  Item not in place          Book        0         NaN       0         0
# 337  Item not in place          Book        0         NaN       0         0
#
#                MMS ID
# 0    9922033313606241
# 1    9922023283606241
# 2    9917370583606241
# 3     998483803606241
# 4     998635113606241
# ..                ...
# 331  9910328073606241
# 333  9923787673606241
# 334   994906973606241
# 336  9919460473606241
# 337  9924929003606241
#
# [244 rows x 14 columns]

# %%
nov_lost_df["Type / Creator / Imprint"]
# Out:
# 0            Book By Lawrence, Mark (Ace Books 20170404)
# 1              Book By Livesey, Margot (Harper 20160927)
# 2      Book By Smith, Pamela H., (Ann Arbor : Univers...
# 3      Book By Csikszentmihalyi, Mihaly. (Oxford ; Ne...
# 4      Book By Ong, Anthony D. (Oxford ; New York : O...
#                              ...
# 331    Book By Smith, Desire. (Atglen, PA : Schiffer ...
# 333    Book By Borsuk, Amaranth, (Cambridge, MA : The...
# 334    Book By Dorsheimer, Wesley. (New York : Hippoc...
# 336    Book By Walsh, Brighton (Berkley Publishing Gr...
# 337         Book By Weldon, Fay. (Head of Zeus 20180401)
# Name: Type / Creator / Imprint, Length: 244, dtype: object

# %%
nov_lost_df["Type / Creator / Imprint"] = nov_lost_df["Type / Creator / Imprint"].str.replace(r"(Book By)", "")
nov_lost_df["Type / Creator / Imprint"]
# Out:
# <ipython-input-18-0ad5ce3283c3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nov_lost_df["Type / Creator / Imprint"] = nov_lost_df["Type / Creator / Imprint"].str.replace(r"(Book By)", "")
# 0                    Lawrence, Mark (Ace Books 20170404)
# 1                      Livesey, Margot (Harper 20160927)
# 2       Smith, Pamela H., (Ann Arbor : University of ...
# 3       Csikszentmihalyi, Mihaly. (Oxford ; New York ...
# 4       Ong, Anthony D. (Oxford ; New York : Oxford U...
#                              ...
# 331     Smith, Desire. (Atglen, PA : Schiffer Pub Ltd...
# 333     Borsuk, Amaranth, (Cambridge, MA : The MIT Pr...
# 334     Dorsheimer, Wesley. (New York : Hippocrene Bo...
# 336     Walsh, Brighton (Berkley Publishing Group 201...
# 337                 Weldon, Fay. (Head of Zeus 20180401)
# Name: Type / Creator / Imprint, Length: 244, dtype: object

# %%
nov_lost_df["Type / Creator / Imprint"] = nov_lost_df["Type / Creator / Imprint"].str.replace(r"(Music By)","")
nov_lost_df["Type / Creator / Imprint"]
# Out:
# <ipython-input-19-a0b31ece3941>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nov_lost_df["Type / Creator / Imprint"] = nov_lost_df["Type / Creator / Imprint"].str.replace(r"(Music By)","")
# 0                    Lawrence, Mark (Ace Books 20170404)
# 1                      Livesey, Margot (Harper 20160927)
# 2       Smith, Pamela H., (Ann Arbor : University of ...
# 3       Csikszentmihalyi, Mihaly. (Oxford ; New York ...
# 4       Ong, Anthony D. (Oxford ; New York : Oxford U...
#                              ...
# 331     Smith, Desire. (Atglen, PA : Schiffer Pub Ltd...
# 333     Borsuk, Amaranth, (Cambridge, MA : The MIT Pr...
# 334     Dorsheimer, Wesley. (New York : Hippocrene Bo...
# 336     Walsh, Brighton (Berkley Publishing Group 201...
# 337                 Weldon, Fay. (Head of Zeus 20180401)
# Name: Type / Creator / Imprint, Length: 244, dtype: object

# %%
nov_lost_df["Type / Creator / Imprint"] = nov_lost_df["Type / Creator / Imprint"].str.replace(r"[\(\[].*?[\)\]]","")
nov_lost_df["Type / Creator / Imprint"]
# Out:
# <ipython-input-20-97dd2a18537f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nov_lost_df["Type / Creator / Imprint"] = nov_lost_df["Type / Creator / Imprint"].str.replace(r"[\(\[].*?[\)\]]","")
# 0                  Lawrence, Mark
# 1                 Livesey, Margot
# 2              Smith, Pamela H., )
# 3       Csikszentmihalyi, Mihaly.
# 4                 Ong, Anthony D.
#                   ...
# 331                Smith, Desire.
# 333            Borsuk, Amaranth, )
# 334           Dorsheimer, Wesley.
# 336               Walsh, Brighton
# 337                  Weldon, Fay.
# Name: Type / Creator / Imprint, Length: 244, dtype: object

# %%
nov_lost_df["Type / Creator / Imprint"] = nov_lost_df["Type / Creator / Imprint"].str.replace(r"[\d]","")
nov_lost_df["Type / Creator / Imprint"]
# Out:
# <ipython-input-21-35d1e9845d52>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nov_lost_df["Type / Creator / Imprint"] = nov_lost_df["Type / Creator / Imprint"].str.replace(r"[\d]","")
# 0                  Lawrence, Mark
# 1                 Livesey, Margot
# 2              Smith, Pamela H., )
# 3       Csikszentmihalyi, Mihaly.
# 4                 Ong, Anthony D.
#                   ...
# 331                Smith, Desire.
# 333            Borsuk, Amaranth, )
# 334           Dorsheimer, Wesley.
# 336               Walsh, Brighton
# 337                  Weldon, Fay.
# Name: Type / Creator / Imprint, Length: 244, dtype: object

# %%
nov_lost_df["Type / Creator / Imprint"] = nov_lost_df["Type / Creator / Imprint"].str.replace(r"[\)]","")
nov_lost_df["Type / Creator / Imprint"]
# Out:
# <ipython-input-22-3ee79621327d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nov_lost_df["Type / Creator / Imprint"] = nov_lost_df["Type / Creator / Imprint"].str.replace(r"[\)]","")
# 0                  Lawrence, Mark
# 1                 Livesey, Margot
# 2               Smith, Pamela H.,
# 3       Csikszentmihalyi, Mihaly.
# 4                 Ong, Anthony D.
#                   ...
# 331                Smith, Desire.
# 333             Borsuk, Amaranth,
# 334           Dorsheimer, Wesley.
# 336               Walsh, Brighton
# 337                  Weldon, Fay.
# Name: Type / Creator / Imprint, Length: 244, dtype: object

# %%
nov_lost_df["Type / Creator / Imprint"] = nov_lost_df["Type / Creator / Imprint"].str.replace(r"[\.]","")
nov_lost_df["Type / Creator / Imprint"]
# Out:
# <ipython-input-23-e067cd8bbe33>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nov_lost_df["Type / Creator / Imprint"] = nov_lost_df["Type / Creator / Imprint"].str.replace(r"[\.]","")
# 0                 Lawrence, Mark
# 1                Livesey, Margot
# 2               Smith, Pamela H,
# 3       Csikszentmihalyi, Mihaly
# 4                 Ong, Anthony D
#                   ...
# 331                Smith, Desire
# 333            Borsuk, Amaranth,
# 334           Dorsheimer, Wesley
# 336              Walsh, Brighton
# 337                  Weldon, Fay
# Name: Type / Creator / Imprint, Length: 244, dtype: object

# %%
nov_lost_df["Type / Creator / Imprint"] = nov_lost_df["Type / Creator / Imprint"].str.replace(r"[\,]", "")
nov_lost_df["Type / Creator / Imprint"]
# Out:
# <ipython-input-24-826806b12ca9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nov_lost_df["Type / Creator / Imprint"] = nov_lost_df["Type / Creator / Imprint"].str.replace(r"[\,]", "")
# 0                 Lawrence Mark
# 1                Livesey Margot
# 2                Smith Pamela H
# 3       Csikszentmihalyi Mihaly
# 4                 Ong Anthony D
#                  ...
# 331                Smith Desire
# 333             Borsuk Amaranth
# 334           Dorsheimer Wesley
# 336              Walsh Brighton
# 337                  Weldon Fay
# Name: Type / Creator / Imprint, Length: 244, dtype: object

# %%
nov_lost_df["Type / Creator / Imprint"][0]
# Out:
# ' Lawrence Mark '

# %%
nov_lost_df
# Out:
#       Type / Creator / Imprint  \
# 0               Lawrence Mark
# 1              Livesey Margot
# 2              Smith Pamela H
# 3     Csikszentmihalyi Mihaly
# 4               Ong Anthony D
# ..                         ...
# 331              Smith Desire
# 333           Borsuk Amaranth
# 334         Dorsheimer Wesley
# 336            Walsh Brighton
# 337                Weldon Fay
#
#                                                  title         Barcode  \
# 0                                           Red Sister  33082012289335
# 1                                              Mercury  33082012283122
# 2    Ways of making and knowing : the material cult...  33082011802245
# 3    A life worth living : contributions to positiv...  33082009480889
# 4    Oxford handbook of methods in positive psychol...  33082009900084
# ..                                                 ...             ...
# 331  Fashionable clothing from the Sears catalogs :...  33082010381969
# 333                        The book / Amaranth Borsuk.  33082012427471
# 334  The newsletter handbook : how to write and pub...  33082005551501
# 336                                    Caged in Winter  33082012284047
# 337                               Death of a She Devil  33082012492483
#
#     Modification Date Due Date    Permanent Location        Call Number  \
# 0              08-Nov   16-Sep  Recreational Reading                  F
# 1              08-Nov   16-Sep  Recreational Reading                  F
# 2              08-Nov   16-Sep                 Books    AZ101 .W39 2014
# 3              08-Nov   16-Sep                 Books  BF204.6 .L54 2006
# 4              08-Nov   16-Sep                 Books  BF204.6 .O94 2007
# ..                ...      ...                   ...                ...
# 331            08-Nov   16-Sep                 Books    TT555 .S62 1998
# 333            14-Nov   24-Sep                 Books       Z4 .B74 2018
# 334            08-Nov   16-Sep                 Books  Z286.N46 D67 1993
# 336            07-Nov   16-Sep  Recreational Reading                  F
# 337            07-Nov   16-Sep  Recreational Reading                  F
#
#                 Status Material Type  Copy ID Description  Orders  Requests  \
# 0    Item not in place          Book        0         NaN       0         0
# 1    Item not in place          Book        0         NaN       0         0
# 2    Item not in place          Book        0         NaN       0         0
# 3    Item not in place          Book        0         NaN       0         0
# 4    Item not in place          Book        0         NaN       0         0
# ..                 ...           ...      ...         ...     ...       ...
# 331  Item not in place          Book        0         NaN       0         0
# 333  Item not in place          Book        0         NaN       0         0
# 334  Item not in place          Book        0         NaN       0         0
# 336  Item not in place          Book        0         NaN       0         0
# 337  Item not in place          Book        0         NaN       0         0
#
#                MMS ID
# 0    9922033313606241
# 1    9922023283606241
# 2    9917370583606241
# 3     998483803606241
# 4     998635113606241
# ..                ...
# 331  9910328073606241
# 333  9923787673606241
# 334   994906973606241
# 336  9919460473606241
# 337  9924929003606241
#
# [244 rows x 14 columns]

# %%
nov_final = nov_lost_df[["Barcode","title", "Type / Creator / Imprint", "Call Number","Permanent Location", "Material Type", "Copy ID", "Description", "Orders", "Requests", "Modification Date", "Due Date"]]
nov_final = nov_final.rename(columns={"Type / Creator / Imprint": "Author"})
nov_final
# Out:
#             Barcode                                              title  \
# 0    33082012289335                                         Red Sister
# 1    33082012283122                                            Mercury
# 2    33082011802245  Ways of making and knowing : the material cult...
# 3    33082009480889  A life worth living : contributions to positiv...
# 4    33082009900084  Oxford handbook of methods in positive psychol...
# ..              ...                                                ...
# 331  33082010381969  Fashionable clothing from the Sears catalogs :...
# 333  33082012427471                        The book / Amaranth Borsuk.
# 334  33082005551501  The newsletter handbook : how to write and pub...
# 336  33082012284047                                    Caged in Winter
# 337  33082012492483                               Death of a She Devil
#
#                         Author        Call Number    Permanent Location  \
# 0               Lawrence Mark                   F  Recreational Reading
# 1              Livesey Margot                   F  Recreational Reading
# 2              Smith Pamela H     AZ101 .W39 2014                 Books
# 3     Csikszentmihalyi Mihaly   BF204.6 .L54 2006                 Books
# 4               Ong Anthony D   BF204.6 .O94 2007                 Books
# ..                         ...                ...                   ...
# 331              Smith Desire     TT555 .S62 1998                 Books
# 333           Borsuk Amaranth        Z4 .B74 2018                 Books
# 334         Dorsheimer Wesley   Z286.N46 D67 1993                 Books
# 336            Walsh Brighton                   F  Recreational Reading
# 337                Weldon Fay                   F  Recreational Reading
#
#     Material Type  Copy ID Description  Orders  Requests Modification Date  \
# 0            Book        0         NaN       0         0            08-Nov
# 1            Book        0         NaN       0         0            08-Nov
# 2            Book        0         NaN       0         0            08-Nov
# 3            Book        0         NaN       0         0            08-Nov
# 4            Book        0         NaN       0         0            08-Nov
# ..            ...      ...         ...     ...       ...               ...
# 331          Book        0         NaN       0         0            08-Nov
# 333          Book        0         NaN       0         0            14-Nov
# 334          Book        0         NaN       0         0            08-Nov
# 336          Book        0         NaN       0         0            07-Nov
# 337          Book        0         NaN       0         0            07-Nov
#
#     Due Date
# 0     16-Sep
# 1     16-Sep
# 2     16-Sep
# 3     16-Sep
# 4     16-Sep
# ..       ...
# 331   16-Sep
# 333   24-Sep
# 334   16-Sep
# 336   16-Sep
# 337   16-Sep
#
# [244 rows x 12 columns]

# %%
nov_final.to_csv("nov_final.csv")
